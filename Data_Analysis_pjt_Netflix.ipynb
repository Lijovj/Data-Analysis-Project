# %% [markdown]
# <a href="https://colab.research.google.com/github/Lijovj/Data-Analysis-Project/blob/main/Data_Analysis_pjt_Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This dataset consists of tv shows and movies available on Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix
# search engine.  In 2018, they released an interesting report which shows that the number of TV shows on Netflix has nearly tripled since 2010. The
# streaming service’s number of movies has decreased by more than 2,000 titles since 2010, while its number of TV shows has nearly tripled. It will be
# interesting to explore what all other insights can be obtained from the same dataset. Integrating this dataset with other external datasets such as
# IMDB ratings, rotten tomatoes can also provide many interesting findings.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# * How many movies available, which are released year 2020

# %%
df = pd.read_csv('/content/netflix_titles.csv')
df.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.shape
# Out:
# (7787, 12)

# %%
df['release_year'].value_counts()
# Out:
# 2018    1121
# 2017    1012
# 2019     996
# 2016     882
# 2020     868
#         ...
# 1966       1
# 1947       1
# 1959       1
# 1964       1
# 1925       1
# Name: release_year, Length: 73, dtype: int64

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.isnull().sum() !=0

# %%
df.isnull().sum()[df.isnull().sum()!=0].plot(kind='bar')

# %%
df.describe()

# %%
df.title.describe()
# Out:
# count                7787
# unique               7787
# top       Caida del Cielo
# freq                    1
# Name: title, dtype: object

# %%
df.country.unique()
# Out:
# array(['Brazil', 'Mexico', 'Singapore', 'United States', 'Turkey',
#        'Egypt', 'India', 'Poland, United States', 'Thailand', 'Nigeria',
#        nan, 'Norway, Iceland, United States', 'United Kingdom', 'Japan',
#        'South Korea', 'Italy', 'Canada', 'Indonesia', 'Romania', 'Spain',
#        'Iceland', 'South Africa, Nigeria', 'France',
#        'United States, South Africa', 'Portugal, Spain',
#        'Hong Kong, China, Singapore', 'United States, Germany',
#        'South Africa, China, United States', 'Argentina',
#        'United States, France, Serbia', 'Germany',
#        'Denmark, France, Poland', 'Poland', 'Kenya',
#        'New Zealand, United Kingdom', 'Pakistan', 'Australia',
#        'Australia, United States', 'Mexico, United States',
#        'United States, China', 'China, Hong Kong', 'Taiwan',
#        'United States, United Kingdom', 'France, South Korea, Japan',
#        'United States, Canada', 'United Kingdom, United States',
# ...

# %%
df.country.value_counts()
# Out:
# United States                                        2555
# India                                                 923
# United Kingdom                                        397
# Japan                                                 226
# South Korea                                           183
#                                                      ...
# Saudi Arabia, United Arab Emirates                      1
# United States, France, Serbia                           1
# Finland, Sweden, Norway, Latvia, Germany                1
# United States, Germany, Mexico                          1
# United States, United Kingdom, Spain, South Korea       1
# Name: country, Length: 681, dtype: int64

# %%
plt.hist(df.release_year,bins=20,edgecolor='k')

# %%
cat_col = df.select_dtypes(include='object')
cat_col

# %%
cat_col.apply(lambda x : x.unique())

# %%
(df.type.value_counts()/df.shape[0]).plot(kind='bar')

# %%
sns.countplot(x='type',data=df)
plt.show()

# %%
rc_df = df[df.country == 'India']
sns.countplot(x='type',data=rc_df,hue='release_year')
plt.show()

# %%
df[['type','country','release_year']]
# Out:
#          type                                            country  release_year
# 0     TV Show                                             Brazil          2020
# 1       Movie                                             Mexico          2016
# 2       Movie                                          Singapore          2011
# 3       Movie                                      United States          2009
# 4       Movie                                      United States          2008
# ...       ...                                                ...           ...
# 7782    Movie  Sweden, Czech Republic, United Kingdom, Denmar...          2005
# 7783    Movie                                              India          2015
# 7784    Movie                                                NaN          2019
# 7785  TV Show                                          Australia          2019
# 7786    Movie              United Kingdom, Canada, United States          2019
#
# [7787 rows x 3 columns]

# %%
c = df[df['country'] == 'India']
c
# Out:
#      show_id  ...                                        description
# 8         s9  ...  When a doctor goes missing, his psychiatrist w...
# 9        s10  ...  An architect and his wife move into a castle t...
# 18       s19  ...  On India's Independence Day, a zany mishap in ...
# 20       s21  ...  After accidentally connecting over the Interne...
# 21       s22  ...  A taxi driver, a gangster and an athlete strug...
# ...      ...  ...                                                ...
# 7764   s7765  ...  Through his relationships with two wildly diff...
# 7769   s7770  ...  Three friends on an adventurous road trip/bach...
# 7776   s7777  ...  When his cruel uncle abandons him, a young orp...
# 7780   s7781  ...  A drug dealer starts having doubts about his t...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
#
# [923 rows x 12 columns]

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='release_year',data=c,hue='type')
plt.xticks(rotation=90)
plt.show()

# %%
u = df[df['country'] == 'United States']
u

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='release_year',data=u,hue='type')
plt.xticks(rotation=90)
plt.show()

# %%
d_add = df[df['type'] == 'TV Show']
d_add
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 5         s6  ...  A genetics professor experiments with a treatm...
# 11       s12  ...  In this dark alt-history thriller, a naïve law...
# 12       s13  ...  Archival video and new interviews examine Mexi...
# 16       s17  ...  As a psychology professor faces Alzheimer's, h...
# ...      ...  ...                                                ...
# 7767   s7768  ...  Strong-willed, middle-class Kashaf and carefre...
# 7775   s7776  ...  A quest for freedom and legendary treasure beg...
# 7777   s7778  ...  While living alone in a spooky town, a young g...
# 7779   s7780  ...  An assortment of talent takes the stage for a ...
# 7785   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
#
# [2410 rows x 12 columns]

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='release_year',data=d_add,hue='country')
plt.xticks(rotation=90)
plt.show()
